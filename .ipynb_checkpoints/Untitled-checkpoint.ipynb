# %%
list = range(0,7)
a = list[0]
b = list[-1]

print(b)
# Out:
# 6

# %%
n = input("Entrer votre n:")
# Out:
# Entrer votre n:5

# %%
# Out:
# yeah!

# %%
list = range(0,10)
n = int(input("vérifier ce numéro: "))
a = list[0]
b = list[-1]
m = (a+b)/2
while n != m:
    m = (a+b)/2

    if m>n:
        b = round(m)
        print(b)
    elif m<n:
        a = round(m)
        print(a)  
        
if n == m:
    print("ok")
