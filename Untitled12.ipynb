# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
x = np.arange(0, 15, 0.001)
x
# Out:
# array([0.0000e+00, 1.0000e-03, 2.0000e-03, ..., 1.4997e+01, 1.4998e+01,
#        1.4999e+01])

# %%
y = (1/2)*x**3 - 7*x**2 + 5*x + 12
y
# Out:
# array([ 12.        ,  12.004993  ,  12.009972  , ..., 199.10263949,
#        199.235062  , 199.3675155 ])

# %%
data = {'x': x, 'y': y}
dataset = pd.DataFrame(data=data)
dataset.head()
# Out:
#        x          y
# 0  0.000  12.000000
# 1  0.001  12.004993
# 2  0.002  12.009972
# 3  0.003  12.014937
# 4  0.004  12.019888

# %%
sns.lineplot(x=x, y=y, data=dataset)

# %%
y = (1/2)*x**3 - 7*x**2 + 5*x + 12
f = (3/2)*x**2 - 14*x + 5

data2 = {'x': x, 'f': f}
dataset2 = pd.DataFrame(data=data2)

sns.lineplot(x=x, y=y, data=dataset)
sns.lineplot(x=x, y=f, data=dataset2)
sns.lineplot(x=x, y=0, data=dataset)

# %%
gradient = np.gradient(y, x)
gradient = pd.DataFrame(gradient)
sns.lineplot(x=x, y=f, data=dataset2)
sns.lineplot(x=x, y=y, data=dataset)

# %%
abs_dy = np.abs(f)
datax = {'x': x, 'y': y, 'f': f, 'abs_dy': abs_dy}
datasetx = pd.DataFrame(data=datax)
datasetx.describe()
datasetx.loc[datasetx.abs_dy == datasetx.abs_dy.min(), : ]
# Out:
#          x          y         f    abs_dy
# 372  0.372  12.917051 -0.000424  0.000424
