# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv("house_pricing.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sns.relplot(x="LotArea", y="SalePrice", data=data.query('LotArea < 20000 and SalePrice < 500000'))

# %%
sns.relplot(y="LotArea", x="LotFrontage", data=data.query('LotArea < 100000 and LotFrontage < 200'), hue = 'MSSubClass', size = 'SalePrice')

# %%
sales = pd.read_csv("sales_predictions.csv").sample(50)
sales["datetime"] = pd.to_datetime(sales.date)
sales.head()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1866762  20.07.2014              18       24    17255       149.0
# 883566   07.09.2013               8       13    13351        41.0
# 92503    11.01.2013               0       42     9846       149.0
# 1992419  20.09.2014              20       31     7172      2799.0
# 299210   20.03.2013               2       14     6738       699.0
#
#          item_cnt_day   datetime
# 1866762           1.0 2014-07-20
# 883566            1.0 2013-07-09
# 92503             1.0 2013-11-01
# 1992419           1.0 2014-09-20
# 299210            2.0 2013-03-20

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(20, 6))
sns.relplot(x="datetime", y="item_price", data = sales, ax=ax)
plt.show()

# %%
data = pd.read_csv("/users/vincentsalamand/Downloads/IBM_HR_ATTRITION.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
sns.catplot(y="JobSatisfaction", x="Attrition", kind="box", data=data)

# %%
sns.catplot(y="YearsAtCompany", x="Attrition", kind="box", data=data)

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
desc = data.YearsAtCompany.describe()
over_value = desc["75%"]+1.5*(desc["75%"]-desc["25%"])
abb_data = data.query("YearsAtCompany > 18")
abb_data.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  104.000000   104.000000        104.000000  104.000000          104.0
# mean    45.740385   750.951923          9.403846    2.923077            1.0
# std      5.704699   421.319158          8.904585    1.076603            0.0
# min     38.000000   117.000000          1.000000    1.000000            1.0
# 25%     41.000000   385.250000          2.000000    2.000000            1.0
# 50%     44.500000   677.000000          6.500000    3.000000            1.0
# 75%     50.000000  1196.000000         14.000000    4.000000            1.0
# max     60.000000  1449.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      104.000000               104.000000  104.000000      104.000000
# mean       980.759615                 2.673077   65.259615        2.615385
# ...

# %%
sns.catplot(y="TotalWorkingYears", x="Attrition", kind="box", data=data)

# %%
desc = data.TotalWorkingYears.describe()
over_value = desc["75%"]+1.5*(desc["75%"]-desc["25%"])
abb_data = data.query("YearsAtCompany > 18")
abb_data.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  104.000000   104.000000        104.000000  104.000000          104.0
# mean    45.740385   750.951923          9.403846    2.923077            1.0
# std      5.704699   421.319158          8.904585    1.076603            0.0
# min     38.000000   117.000000          1.000000    1.000000            1.0
# 25%     41.000000   385.250000          2.000000    2.000000            1.0
# 50%     44.500000   677.000000          6.500000    3.000000            1.0
# 75%     50.000000  1196.000000         14.000000    4.000000            1.0
# max     60.000000  1449.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      104.000000               104.000000  104.000000      104.000000
# mean       980.759615                 2.673077   65.259615        2.615385
# ...

# %%
data = pd.read_csv("/users/vincentsalamand/Downloads/IBM_HR_ATTRITION.csv")

data["attrition"] = pd.get_dummies(data.Attrition, drop_first = True)



sns.distplot(data.attrition, bins=10)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv("/users/vincentsalamand/Downloads/IBM_HR_ATTRITION.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
sns.distplot(data.MonthlyIncome)

# %%
toto = data.query("MonthlyIncome < 5000")
sns.distplot(toto.MonthlyIncome)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data["attrition"] = pd.get_dummies(data.Attrition, drop_first = True)

sns.lmplot(x="DistanceFromHome", y="attrition", data=data)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x="YearsWithCurrManager", y="attrition", data=data)
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


pricing = pd.read_csv("house_pricing.csv")
pricing = pricing.tail(15)
pricing.corr()
# Out:
#                          Id  MSSubClass  LotFrontage   LotArea   OverallQual  \
# Id             1.000000e+00   -0.299933     0.170671 -0.176641  1.175185e-17
# MSSubClass    -2.999333e-01    1.000000    -0.879089 -0.643601 -2.135655e-01
# LotFrontage    1.706710e-01   -0.879089     1.000000  0.914186  2.928409e-01
# LotArea       -1.766413e-01   -0.643601     0.914186  1.000000 -1.544585e-01
# OverallQual    1.175185e-17   -0.213565     0.292841 -0.154458  1.000000e+00
# OverallCond    1.479836e-01    0.051806    -0.176484  0.150015 -1.694586e-01
# YearBuilt      3.847864e-02    0.052251     0.019051 -0.148001  4.729485e-01
# YearRemodAdd   3.193971e-01   -0.124680     0.211581 -0.204825  3.828724e-01
# MasVnrArea    -3.907955e-01   -0.121045     0.279790  0.251578  5.706548e-01
# BsmtFinSF1    -2.039226e-02    0.098483    -0.049288  0.026653  2.180785e-01
# BsmtFinSF2     2.372469e-01   -0.198927     0.142105 -0.058416 -1.765379e-01
# ...

# %%
corr = pricing.corr()

f, ax = plt.subplots(figsize=(20, 6))
sns.heatmap(corr, annot=True, ax=ax)

# %%
corr.SalePrice
# Out:
# Id               0.185665
# MSSubClass      -0.297952
# LotFrontage      0.320924
# LotArea         -0.015706
# OverallQual      0.858716
# OverallCond      0.113712
# YearBuilt        0.205704
# YearRemodAdd     0.398472
# MasVnrArea       0.537068
# BsmtFinSF1       0.203553
# BsmtFinSF2      -0.191131
# BsmtUnfSF        0.399401
# TotalBsmtSF      0.663625
# 1stFlrSF         0.612721
# 2ndFlrSF         0.346151
# LowQualFinSF          NaN
# GrLivArea        0.736811
# BsmtFullBath    -0.109293
# BsmtHalfBath          NaN
# FullBath         0.750390
# HalfBath        -0.106978
# BedroomAbvGr     0.448422
# KitchenAbvGr    -0.143059
# TotRmsAbvGrd     0.671571
# Fireplaces       0.768226
# GarageYrBlt      0.212667
# GarageCars       0.730890
# GarageArea       0.718423
# WoodDeckSF      -0.135557
# OpenPorchSF      0.281036
# EnclosedPorch   -0.212401
# 3SsnPorch             NaN
# ScreenPorch           NaN
# PoolArea              NaN
# MiscVal          0.453256
# ...

# %%
dada = pd.read_csv("/users/vincentsalamand/Downloads/epicurious-recipes-with-rating-and-nutrition/epi_r.csv")
dada.count()
# Out:
# title                    20052
# rating                   20052
# calories                 15935
# protein                  15890
# fat                      15869
# sodium                   15933
# #cakeweek                20052
# #wasteless               20052
# 22-minute meals          20052
# 3-ingredient recipes     20052
# 30 days of groceries     20052
# advance prep required    20052
# alabama                  20052
# alaska                   20052
# alcoholic                20052
# almond                   20052
# amaretto                 20052
# anchovy                  20052
# anise                    20052
# anniversary              20052
# anthony bourdain         20052
# aperitif                 20052
# appetizer                20052
# apple                    20052
# apple juice              20052
# apricot                  20052
# arizona                  20052
# artichoke                20052
# arugula                  20052
# asian pear               20052
# ...

# %%
del pricing["MSSubClass"], pricing["LotArea"], pricing["BsmtFinSF2"], pricing["LowQualFinSF"], pricing["BsmtFullBath"], pricing["BsmtHalfBath"], pricing["HalfBath"],
pricing["KitchenAbvGr"], pricing["WoodDeckSF"], pricing["EnclosedPorch"], pricing["MoSold"],
pricing["3SsnPorch"], pricing["ScreenPorch"], pricing["PoolArea"]

pricing.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MSSubClass'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-215-2326b47f1370> in <module>
# ...
