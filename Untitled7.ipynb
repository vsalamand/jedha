# %%
import pandas as pd

# %%
dataframe = pd.DataFrame({"col_1": [213, 4234, 328],
                         "col_2": [327, 36823,932]})

# %%
dataframe
# Out:
#    col_1  col_2
# 0    213    327
# 1   4234  36823
# 2    328    932

# %%
dataframe.mean()
# Out:
# col_1     1591.666667
# col_2    12694.000000
# dtype: float64

# %%
pd.Series([323, 823, 7637], name="nom")
# Out:
# 0     323
# 1     823
# 2    7637
# Name: nom, dtype: int64

# %%
import numpy as np

# %%
dataframe = dataframe.values

# %%
dataframe
# Out:
# array([[  213,   327],
#        [ 4234, 36823],
#        [  328,   932]])

# %%
dataset = pd.read_csv("/users/vincentsalamand/Downloads/chipotle.csv")

# %%
dataset.head(10)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# ...

# %%
dataset.tail()
# Out:
#       Unnamed: 0  order_id  quantity           item_name  \
# 4617        4617      1833         1       Steak Burrito
# 4618        4618      1833         1       Steak Burrito
# 4619        4619      1834         1  Chicken Salad Bowl
# 4620        4620      1834         1  Chicken Salad Bowl
# 4621        4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
dataset.median()
# Out:
# Unnamed: 0    2310.5
# order_id       926.0
# quantity         1.0
# dtype: float64

# %%
dataset.describe()
# Out:
#         Unnamed: 0     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2310.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       0.000000     1.000000     1.000000
# 25%    1155.250000   477.250000     1.000000
# 50%    2310.500000   926.000000     1.000000
# 75%    3465.750000  1393.000000     1.000000
# max    4621.000000  1834.000000    15.000000

# %%
dataset.shape
# Out:
# (4622, 6)

# %%
dataset.groupby("item_name")

# %%
dataset.groupby("item_name").sum().sort_values(["quantity"], ascending = False)
# Out:
#                                        Unnamed: 0  order_id  quantity
# item_name
# Chicken Bowl                              1779909    713926       761
# Chicken Burrito                           1238217    497303       591
# Chips and Guacamole                       1121773    449959       506
# Steak Burrito                              817795    328437       386
# Canned Soft Drink                          759990    304753       351
# Chips                                      518704    208004       230
# Steak Bowl                                 482721    193752       221
# Bottled Water                              439354    175944       211
# Chips and Fresh Tomato Salsa               250144    100419       130
# Canned Soda                                189915     76396       126
# Chicken Salad Bowl                         292292    117104       123
# Chicken Soft Tacos                         244891     98395       120
# ...

# %%
dataset.quantity.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# Name: quantity, dtype: int64

# %%
dataset["quantity"].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# Name: quantity, dtype: int64

# %%
dataset.loc[3:7, "item_price"].head()
# Out:
# 3     $2.39
# 4    $16.98
# 5    $10.98
# 6     $1.69
# 7    $11.75
# Name: item_price, dtype: object

# %%
dataset.iloc[:, -1].head()
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: object

# %%
dataset.iloc[1,3]
# Out:
# 'Izze'

# %%
dataset.iloc[0,-1]
# Out:
# '$2.39 '

# %%
new_data = [x.replace("$", "") for x in dataset.item_price.head()]
new_data
# Out:
# ['2.39 ', '3.39 ', '3.39 ', '2.39 ', '16.98 ']

# %%
dataset.item_price.str.replace("$", "").head()
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: item_price, dtype: object

# %%
dataset.item_price.str[1:].head()
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: item_price, dtype: object

# %%
type(dataset.item_price[1])
# Out:
# str

# %%
type(float(dataset.item_price.str[1:][1]))
# Out:
# float

# %%
data = dataset.item_price.str.replace("$", "").head()
#pd.Series(DATA, name="", dtype='float')
toto = pd.Series(data, name="item_price", dtype='float')
toto
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: item_price, dtype: float64

# %%
dataset = pd.read_csv("/users/vincentsalamand/Downloads/chipotle.csv")
dataset.item_price = pd.Series(dataset.item_price.str.replace("$", ""), dtype='float')
dataset.groupby("item_name").sum().sort_values(["quantity"], ascending = False)
# Out:
#                                        Unnamed: 0  order_id  quantity  \
# item_name
# Chicken Bowl                              1779909    713926       761
# Chicken Burrito                           1238217    497303       591
# Chips and Guacamole                       1121773    449959       506
# Steak Burrito                              817795    328437       386
# Canned Soft Drink                          759990    304753       351
# Chips                                      518704    208004       230
# Steak Bowl                                 482721    193752       221
# Bottled Water                              439354    175944       211
# Chips and Fresh Tomato Salsa               250144    100419       130
# Canned Soda                                189915     76396       126
# Chicken Salad Bowl                         292292    117104       123
# Chicken Soft Tacos                         244891     98395       120
# ...

# %%
dataset = pd.read_csv("/users/vincentsalamand/Downloads/chipotle.csv")
dataset.item_price = dataset.item_price.astype(float)
dataset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-b05bda018f80> in <module>
#       1 dataset = pd.read_csv("/users/vincentsalamand/Downloads/chipotle.csv")
# ----> 2 dataset.item_price = dataset.item_price.astype(float)
#       3 dataset
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
dataset = pd.read_csv("/users/vincentsalamand/Downloads/chipotle.csv")
dataset.item_price = dataset.item_price.apply(lambda x: float(x[1:]))
dataset.head()
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
dataset.apply(lambda x: ____ if ____ else _____ if ____ else _____)

# %%
dataset[dataset.loc[:, "item_price"] ==3.39].head()
# Out:
#     Unnamed: 0  order_id  quantity         item_name    choice_description  \
# 1            1         1         1              Izze          [Clementine]
# 2            2         1         1  Nantucket Nectar               [Apple]
# 22          22        11         1  Nantucket Nectar  [Pomegranate Cherry]
# 24          24        12         1              Izze          [Grapefruit]
# 47          47        21         1              Izze          [Blackberry]
#
#     item_price
# 1         3.39
# 2         3.39
# 22        3.39
# 24        3.39
# 47        3.39

# %%
dataset.query("item_name == 'Izze' and item_price==3.39").head()
# Out:
#      Unnamed: 0  order_id  quantity item_name choice_description  item_price
# 1             1         1         1      Izze       [Clementine]        3.39
# 24           24        12         1      Izze       [Grapefruit]        3.39
# 47           47        21         1      Izze       [Blackberry]        3.39
# 66           66        30         1      Izze       [Blackberry]        3.39
# 359         359       155         1      Izze       [Blackberry]        3.39

# %%
dataset = pd.read_csv("/users/vincentsalamand/Downloads/chipotle.csv")
dataset.item_price = dataset.item_price.apply(lambda x: float(x[1:]))

dataset["revenue"] = dataset.quantity * dataset.item_price

# %%
dataset.describe()
# Out:
#         Unnamed: 0     order_id     quantity   item_price      revenue
# count  4622.000000  4622.000000  4622.000000  4622.000000  4622.000000
# mean   2310.500000   927.254868     1.075725     7.464336     8.489186
# std    1334.400802   528.890796     0.410186     4.245557    12.632060
# min       0.000000     1.000000     1.000000     1.090000     1.090000
# 25%    1155.250000   477.250000     1.000000     3.390000     3.990000
# 50%    2310.500000   926.000000     1.000000     8.750000     8.750000
# 75%    3465.750000  1393.000000     1.000000     9.250000    10.980000
# max    4621.000000  1834.000000    15.000000    44.250000   663.750000
