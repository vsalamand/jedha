# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
dataset = pd.read_csv("/Users/vincentsalamand/Downloads/speeddating.csv")
pd.options.display.max_columns = None

dataset.head()
# Out:
#    has_null  wave  gender age age_o  d_age d_d_age  \
# 0         0     1  female  21    27      6   [4-6]
# 1         0     1  female  21    22      1   [0-1]
# 2         1     1  female  21    22      1   [0-1]
# 3         0     1  female  21    23      2   [2-3]
# 4         0     1  female  21    24      3   [2-3]
#
#                                       race  \
# 0  'Asian/Pacific Islander/Asian-American'
# 1  'Asian/Pacific Islander/Asian-American'
# 2  'Asian/Pacific Islander/Asian-American'
# 3  'Asian/Pacific Islander/Asian-American'
# 4  'Asian/Pacific Islander/Asian-American'
#
#                                     race_o  samerace importance_same_race  \
# 0              European/Caucasian-American         0                    2
# 1              European/Caucasian-American         0                    2
# 2  'Asian/Pacific Islander/Asian-American'         1                    2
# 3              European/Caucasian-American         0                    2
# ...

# %%
dataset = dataset.loc[:, :'match_es']
saved = dataset[['dec', 'attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob', 'met', 'match_es']].copy()
dataset = dataset.loc[:, :'expnum']
dataset = pd.concat([dataset,saved], axis=1)
dataset.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
dataset.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
dataset.iid.nunique()

dataset.count()
dataset.isna().sum()
dataset.isnull().sum() * 100 / len(dataset)
# Out:
# iid          0.000000
# id           0.011936
# gender       0.000000
# idg          0.000000
# condtn       0.000000
# wave         0.000000
# round        0.000000
# position     0.000000
# positin1    22.033898
# order        0.000000
# partner      0.000000
# pid          0.119360
# match        0.000000
# int_corr     1.885892
# samerace     0.000000
# age_o        1.241346
# race_o       0.871330
# pf_o_att     1.062306
# pf_o_sin     1.062306
# pf_o_int     1.062306
# pf_o_fun     1.169730
# pf_o_amb     1.277154
# pf_o_sha     1.539747
# dec_o        0.000000
# attr_o       2.530437
# sinc_o       3.425639
# intel_o      3.652423
# fun_o        4.296968
# amb_o        8.617809
# shar_o      12.843161
#               ...
# sports       0.942946
# tvsports     0.942946
# exercise     0.942946
# dining       0.942946
# museums      0.942946
# art          0.942946
# hiking       0.942946
# gaming       0.942946
# clubbing     0.942946
# reading      0.942946
# ...

# %%
dataset.head()
# Out:
#    has_null  wave  gender age age_o  d_age d_d_age  \
# 0         0     1  female  21    27      6   [4-6]
# 1         0     1  female  21    22      1   [0-1]
# 2         1     1  female  21    22      1   [0-1]
# 3         0     1  female  21    23      2   [2-3]
# 4         0     1  female  21    24      3   [2-3]
#
#                                       race  \
# 0  'Asian/Pacific Islander/Asian-American'
# 1  'Asian/Pacific Islander/Asian-American'
# 2  'Asian/Pacific Islander/Asian-American'
# 3  'Asian/Pacific Islander/Asian-American'
# 4  'Asian/Pacific Islander/Asian-American'
#
#                                     race_o  samerace importance_same_race  \
# 0              European/Caucasian-American         0                    2
# 1              European/Caucasian-American         0                    2
# 2  'Asian/Pacific Islander/Asian-American'         1                    2
# 3              European/Caucasian-American         0                    2
# ...

# %%
preferences = dataset[['gender', 'pf_o_att', 'pf_o_sin', 'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha']].copy()
rating_by_partner = dataset[['gender', 'attr_o', 'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o', 'prob_o']].copy()
rate_your_partner = dataset[['gender', 'attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob']].copy()

preferences.groupby("gender").mean()
# Out:
#          pf_o_att   pf_o_sin   pf_o_int   pf_o_fun   pf_o_amb   pf_o_sha
# gender
# 0       26.893883  16.497231  19.545869  17.769880   8.554378  10.996568
# 1       18.055224  18.305008  21.002502  17.147292  12.827222  12.704194

# %%
rating_by_partner.groupby("gender").mean()
# Out:
#           attr_o    sinc_o   intel_o     fun_o     amb_o    shar_o    like_o  \
# gender
# 0       6.461401  7.251053  7.291202  6.520164  6.604591  5.541148  6.276097
# 1       5.919422  7.099778  7.447362  6.280555  6.952773  5.407012  5.991850
#
#           prob_o
# gender
# 0       5.200866
# 1       5.215672

# %%
rate_your_partner.groupby("gender").mean()
# Out:
#             attr      sinc     intel       fun       amb      shar      like  \
# gender
# 0       5.919300  7.099778  7.447362  6.280555  6.952773  5.407012  5.991850
# 1       6.460029  7.250680  7.289988  6.519866  6.603278  5.540373  6.274933
#
#             prob
# gender
# 0       5.215672
# 1       5.199432
